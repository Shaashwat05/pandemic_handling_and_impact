# %%
#Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.api as sm

# %% [markdown]
# ### Correlation Analysis for April Data

# %%
df_apr = pd.read_csv('COVIDiSTRESS_April_27.csv')

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_apr.corr('spearman'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_apr.corr('pearson'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlation Analysis for May Data

# %%
df_may = pd.read_csv('COVIDiSTRESS_May_30.csv')

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_may.corr('spearman'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_may.corr('pearson'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlation Analysis for June Data

# %%
df_june = pd.read_csv('COVIDiSTRESS_June_17.csv')

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_june.corr('spearman'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_june.corr('pearson'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Ordinary Least Squares Regression Analysis with the PSS10_avg (perceived stress level) as the target and 24 different Expl_Distress columns as features

# %%
Expl_cols = [col for col in df.columns if 'Expl_Distress' in col]
for exCol in Expl_cols:
     df_apr = df_apr[df_apr[exCol].notna()]

# %%
X = df_apr.iloc[:,19:43].values
y = df_apr.iloc[:,:1].values

# %%
print(len(X))
print(len(y))
# Out:
# 84758
# 84758

# %%
ols = sm.OLS(y, X)
ols_res = ols.fit()
ols_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.944
# Model:                            OLS   Adj. R-squared (uncentered):              0.944
# Method:                 Least Squares   F-statistic:                          5.989e+04
# Date:                Tue, 25 Oct 2022   Prob (F-statistic):                        0.00
# Time:                        11:34:50   Log-Likelihood:                         -82987.
# No. Observations:               84758   AIC:                                  1.660e+05
# Df Residuals:                   84734   BIC:                                  1.662e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0369      0.001     26.488      0.000       0.034       0.040
# x2             0.0448      0.001     31.182      0.000       0.042       0.048
# x3             0.0075      0.001      5.740      0.000       0.005       0.010
# x4             0.0140      0.001      9.780      0.000       0.011       0.017
# x5             0.0345      0.002     20.296      0.000       0.031       0.038
# x6             0.0053      0.002      3.082      0.002       0.002       0.009
# x7            -0.0133      0.001    -12.867      0.000      -0.015      -0.011
# x8             0.0198      0.001     16.341      0.000       0.017       0.022
# x9             0.0063      0.001      5.143      0.000       0.004       0.009
# x10            0.0594      0.002     35.286      0.000       0.056       0.063
# x11            0.0207      0.002     12.479      0.000       0.017       0.024
# x12            0.0469      0.002     19.495      0.000       0.042       0.052
# x13            0.0508      0.002     22.688      0.000       0.046       0.055
# x14            0.0287      0.002     15.903      0.000       0.025       0.032
# x15           -0.0049      0.001     -3.718      0.000      -0.007      -0.002
# x16            0.0082      0.002      4.943      0.000       0.005       0.011
# x17            0.0197      0.002     13.028      0.000       0.017       0.023
# x18            0.0846      0.002     51.433      0.000       0.081       0.088
# x19            0.0402      0.002     24.685      0.000       0.037       0.043
# x20            0.0027      0.002      1.792      0.073      -0.000       0.006
# x21            0.0405      0.002     26.322      0.000       0.037       0.044
# x22            0.0199      0.002     11.589      0.000       0.017       0.023
# x23            0.0897      0.002     47.992      0.000       0.086       0.093
# x24           -0.0123      0.001     -9.554      0.000      -0.015      -0.010
# ==============================================================================
# Omnibus:                      963.203   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1422.629
# Skew:                           0.130   Prob(JB):                    1.20e-309
# Kurtosis:                       3.579   Cond. No.                         25.7
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Pairplots

# %%
sns.pairplot(df_apr[['PSS10_avg', 'Lon_avg', 'Compliance', 'Dem_age', 'Trust_countrymeasure', 'Dem_dependents']])
