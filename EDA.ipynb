# %%
#Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.api as sm

# %% [markdown]
# ### Correlation Analysis for April Data

# %%
df_apr = pd.read_csv('COVIDiSTRESS_April_27.csv')

# %%
df_apr.corr()
# Out:
#                       PSS10_avg  latitude  longitude  Trust_countrymeasure  \
# PSS10_avg              1.000000 -0.137514   0.037350             -0.118942
# latitude              -0.137514  1.000000   0.155661              0.023121
# longitude              0.037350  0.155661   1.000000              0.053725
# Trust_countrymeasure  -0.118942  0.023121   0.053725              1.000000
# Lon_avg                0.555751  0.034559  -0.036753             -0.037937
# Dem_age               -0.267412  0.125807   0.024265              0.076471
# Dem_dependents        -0.021427  0.001491   0.018838              0.045452
# Corona_concerns_1      0.221650 -0.112835  -0.053781             -0.130973
# Corona_concerns_2      0.237641 -0.118950  -0.143161             -0.146787
# Corona_concerns_3      0.191968 -0.116720  -0.118218             -0.126501
# Corona_concerns_4      0.100333 -0.067365  -0.112809             -0.047545
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_apr.corr('spearman'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_apr.corr('pearson'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlation Analysis for May Data

# %%
df_may = pd.read_csv('COVIDiSTRESS_May_30.csv')

# %%
df_may.corr()
# Out:
#                       PSS10_avg  latitude  longitude  Trust_countrymeasure  \
# PSS10_avg              1.000000 -0.137269   0.026853             -0.115061
# latitude              -0.137269  1.000000   0.230442             -0.007247
# longitude              0.026853  0.230442   1.000000              0.042972
# Trust_countrymeasure  -0.115061 -0.007247   0.042972              1.000000
# Lon_avg                0.557662  0.021624  -0.031578             -0.038512
# Dem_age               -0.274268  0.094136   0.012052              0.086323
# Dem_dependents        -0.014024 -0.016186   0.014769              0.041580
# Corona_concerns_1      0.217242 -0.111475  -0.064918             -0.123478
# Corona_concerns_2      0.233407 -0.115633  -0.143616             -0.143301
# Corona_concerns_3      0.188525 -0.117749  -0.122175             -0.122904
# Corona_concerns_4      0.096436 -0.065167  -0.107985             -0.044837
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_may.corr('spearman'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_may.corr('pearson'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlation Analysis for June Data

# %%
df_june = pd.read_csv('COVIDiSTRESS_June_17.csv')

# %%
df_june.corr()
# Out:
#                       PSS10_avg  latitude  longitude  Trust_countrymeasure  \
# PSS10_avg              1.000000 -0.135502   0.025754             -0.114973
# latitude              -0.135502  1.000000   0.243361             -0.012287
# longitude              0.025754  0.243361   1.000000              0.041013
# Trust_countrymeasure  -0.114973 -0.012287   0.041013              1.000000
# Lon_avg                0.558518  0.019980  -0.031730             -0.039007
# Dem_age               -0.273860  0.079396   0.006992              0.087201
# Dem_dependents        -0.013772 -0.020091   0.012934              0.041530
# Corona_concerns_1      0.216535 -0.108467  -0.064837             -0.123721
# Corona_concerns_2      0.232516 -0.109479  -0.141464             -0.143213
# Corona_concerns_3      0.187951 -0.114456  -0.121288             -0.122743
# Corona_concerns_4      0.095441 -0.060772  -0.106118             -0.045568
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_june.corr('spearman'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
fig.set_size_inches([20,10])
sns.heatmap(df_june.corr('pearson'), cmap='YlGnBu', linecolor='r', linewidths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Ordinary Least Squares Regression Analysis with the PSS10_avg (perceived stress level) as the target and 24 different Expl_Distress columns as features

# %%
Expl_cols = [col for col in df.columns if 'Expl_Distress' in col]
for exCol in Expl_cols:
     df_apr = df_apr[df_apr[exCol].notna()]

# %%
X = df_apr.iloc[:,19:43].values
y = df_apr.iloc[:,:1].values

# %%
print(len(X))
print(len(y))
# Out:
# 83179
# 83179

# %%
ols = sm.OLS(y, X)
ols_res = ols.fit()
ols_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.944
# Model:                            OLS   Adj. R-squared (uncentered):              0.944
# Method:                 Least Squares   F-statistic:                          5.896e+04
# Date:                Tue, 25 Oct 2022   Prob (F-statistic):                        0.00
# Time:                        22:41:56   Log-Likelihood:                         -81279.
# No. Observations:               83179   AIC:                                  1.626e+05
# Df Residuals:                   83155   BIC:                                  1.628e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Pairplots

# %%
sns.pairplot(df_apr[['PSS10_avg', 'Lon_avg', 'Compliance', 'Dem_age', 'Trust_countrymeasure', 'Dem_dependents']])

# %% [markdown]
# ### Comparing the data distributions from different months

# %%
#box-plot using Matplotlib
fig, axs = plt.subplots(1, 3)
axs[0].boxplot(df_apr['Dem_age'], 0, 'gD', showmeans=True)
axs[0].set_title('April_Age')
axs[1].boxplot(df_may['Dem_age'], 0, 'rD', showmeans=True)
axs[1].set_title('May_Age')
axs[2].boxplot(df_june['Dem_age'], 0, 'bD', showmeans=True)
axs[2].set_title('June_Age')
fig.subplots_adjust(left=3, right=4, bottom=0.05, top=0.9,
                    hspace=0.4, wspace=0.3)

plt.show()

print('April Data - Average Age: ', df_apr['Dem_age'].mean())
print('May Data - Average Age: ', df_may['Dem_age'].mean())
print('June Data - Average Age: ', df_june['Dem_age'].mean())
# Out:
# April Data - Average Age:  38.63320068767357
# May Data - Average Age:  39.383823978812266
# June Data - Average Age:  39.4391186077319
